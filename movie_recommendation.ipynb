# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
warnings.filterwarnings('ignore')

# %%
column_names=['User_id',"Item_id","Rating","Timestamp"]

df=pd.read_csv("u.data",sep='\t',names=column_names)

# %%
df.head()
# Out:
#    User_id  Item_id  Rating  Timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
df.shape
# Out:
# (100000, 4)

# %%
df['User_id'].nunique()
# Out:
# 943

# %%
df['Item_id'].nunique()
# Out:
# 1682

# %%
df_item=pd.read_csv("u.item",sep='\|',header=None)

# %%
df_item.head()
# Out:
#    0                  1            2   3   ... 20  21  22  23
# 0   1   Toy Story (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 1   2   GoldenEye (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 2   3  Four Rooms (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 3   4  Get Shorty (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 4   5     Copycat (1995)  01-Jan-1995 NaN  ...  0   1   0   0
#
# [5 rows x 24 columns]

# %%
df_item=df_item[[0,1]]

# %%
df_item.head()
# Out:
#    0                  1
# 0  1   Toy Story (1995)
# 1  2   GoldenEye (1995)
# 2  3  Four Rooms (1995)
# 3  4  Get Shorty (1995)
# 4  5     Copycat (1995)

# %%
df_item.shape
# Out:
# (1682, 2)

# %%
df_item.columns=['Item_id','title']

# %%
df_item.head()
# Out:
#    Item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %% [markdown]
# **Merging dataframes**

# %%
df=pd.merge(df,df_item,on='Item_id')

# %%
df.tail()
# Out:
#        User_id  ...                                              title
# 99995      840  ...                                  Mamma Roma (1962)
# 99996      655  ...                             Eighth Day, The (1996)
# 99997      655  ...                                  Girls Town (1996)
# 99998      655  ...  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999      655  ...                                    Dadetown (1995)
#
# [5 rows x 5 columns]

# %%
df.shape
# Out:
# (100000, 5)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.groupby('title').mean()['Rating'].sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Prefontaine (1997)                              5.0
# Santa with Muscles (1996)                       5.0
# Star Kid (1997)                                 5.0
# Someone Else's America (1995)                   5.0
#                                                ...
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# JLG/JLG - autoportrait de d�cembre (1994)       1.0
# Daens (1992)                                    1.0
# Butterfly Kiss (1995)                           1.0
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# Name: Rating, Length: 1664, dtype: float64

# %%
df.groupby('title').count()['Rating'].sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# � k�ldum klaka (Cold Fever) (1994)              1
# Name: Rating, Length: 1664, dtype: int64

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['Rating'])

# %%
ratings.head()
# Out:
#                              Rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings[' Number of ratings']=pd.DataFrame(df.groupby('title').count()['Rating'])

# %%
ratings.sort_values(by='Rating',ascending=False)
# Out:
#                                               Rating   Number of ratings
# title
# They Made Me a Criminal (1939)                   5.0                   1
# Marlene Dietrich: Shadow and Light (1996)        5.0                   1
# Saint of Fort Washington, The (1993)             5.0                   2
# Someone Else's America (1995)                    5.0                   1
# Star Kid (1997)                                  5.0                   3
# ...                                              ...                 ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0                   1
# King of New York (1990)                          1.0                   1
# Touki Bouki (Journey of the Hyena) (1973)        1.0                   1
# Bloody Child, The (1996)                         1.0                   1
# Crude Oasis, The (1995)                          1.0                   1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings[' Number of ratings'],bins=70)
plt.show()

# %%
plt.hist(ratings['Rating'],bins=70)
plt.show()

# %%
sns.jointplot(x='Rating',y=' Number of ratings',data=ratings,alpha=0.5)

# %%
##Creating Movie reccomendation

# %%
moviemat=df.pivot_table(index='User_id',columns='title',values='Rating')

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# User_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
# ...                            ...  ...                                 ...
# 939                            NaN  ...                                 NaN
# 940                            NaN  ...                                 NaN
# 941                            NaN  ...                                 NaN
# 942                            NaN  ...                                 NaN
# 943                            NaN  ...                                 NaN
#
# ...

# %%
ratings.sort_values(' Number of ratings',ascending=False)
# Out:
#                                       Rating   Number of ratings
# title
# Star Wars (1977)                    4.358491                 583
# Contact (1997)                      3.803536                 509
# Fargo (1996)                        4.155512                 508
# Return of the Jedi (1983)           4.007890                 507
# Liar Liar (1997)                    3.156701                 485
# ...                                      ...                 ...
# Great Day in Harlem, A (1994)       5.000000                   1
# Other Voices, Other Rooms (1997)    3.000000                   1
# Good Morning (1971)                 1.000000                   1
# Girls Town (1996)                   3.000000                   1
# � k�ldum klaka (Cold Fever) (1994)  3.000000                   1
#
# [1664 rows x 2 columns]

# %%
##STar War User rtings
swur=moviemat['Star Wars (1977)']

# %%
simtostarwars=moviemat.corrwith(swur)

# %%
corrstarwars=pd.DataFrame(simtostarwars,columns=["Correlation"])

# %%
corrstarwars.dropna(inplace=True)

# %%
corrstarwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corrstarwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corrstarwars=corrstarwars.join(ratings[' Number of ratings'])

# %%
corrstarwars.head()
# Out:
#                            Correlation   Number of ratings
# title
# 'Til There Was You (1997)     0.872872                   9
# 1-900 (1994)                 -0.645497                   5
# 101 Dalmatians (1996)         0.211132                 109
# 12 Angry Men (1957)           0.184289                 125
# 187 (1997)                    0.027398                  41

# %%
  corrstarwars[corrstarwars[' Number of ratings']>100].sort_values(by='Correlation',ascending=False)
# Out:
#                                                     Correlation   Number of ratings
# title
# Star Wars (1977)                                       1.000000                 583
# Empire Strikes Back, The (1980)                        0.747981                 367
# Return of the Jedi (1983)                              0.672556                 507
# Raiders of the Lost Ark (1981)                         0.536117                 420
# Austin Powers: International Man of Mystery (1997)     0.377433                 130
# ...                                                         ...                 ...
# Edge, The (1997)                                      -0.127167                 113
# As Good As It Gets (1997)                             -0.130466                 112
# Crash (1996)                                          -0.148507                 128
# G.I. Jane (1997)                                      -0.176734                 175
# ...

# %%
##Predicting function

# %%
def predict_movies(movie_name):
  movie_user_rating=moviemat[movie_name]
  similar_to_that_movie=moviemat.corrwith(movie_user_rating)

  corr_movie=pd.DataFrame(similar_to_that_movie,columns=["Correlation"])
  corr_movie.dropna(inplace=True)

  corr_movie=corr_movie.join(ratings[' Number of ratings'])
  final_prediction=corr_movie[corr_movie[' Number of ratings']>100].sort_values(by='Correlation',ascending=False)
  return final_prediction

# %%
#example movie


predictions=predict_movies('Titanic (1997)')

# %%
predictions.head(10)
# Out:
#                                                Correlation   Number of ratings
# title
# Titanic (1997)                                    1.000000                 350
# River Wild, The (1994)                            0.497600                 146
# Abyss, The (1989)                                 0.472103                 151
# Bram Stoker's Dracula (1992)                      0.443560                 120
# True Lies (1994)                                  0.435104                 208
# William Shakespeare's Romeo and Juliet (1996)     0.430243                 106
# Last of the Mohicans, The (1992)                  0.427239                 128
# Outbreak (1995)                                   0.426237                 104
# Die Hard (1988)                                   0.403124                 243
# Frighteners, The (1996)                           0.398516                 115
